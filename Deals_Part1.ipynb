# %% [markdown]
# # Deals Part 1: System Check

# %% [markdown]
# *This Jupyter Notebook is designed to test the local development environment. Possible problems are listed just before each test.*

# %% [markdown]
# ## Library Imports
# If any of these imports fail then the libraries are not loaded into the Anaconda Environment

# %%
# Needed for SQL Alchemy  
from sqlalchemy import create_engine

# All query results are returned as Pandas DataFrames 
import pandas as pd

# Needed for %sql Magic
# %load_ext sql

# %% [markdown]
# ## SQL Alchemy Check
# If this fails then either ...
# * pymysql is missing (check in Anaconda) or
# * the MySQL server is not running or misconfigured
# * the deals database is not loaded into MySQL server

# %%
# Initialize 
engine = create_engine("mysql+pymysql://dealsuser:deals@localhost/deals")
with engine.connect() as conn, conn.begin():
    companies=pd.read_sql('Select * from Companies', conn)
companies
# Out:
#      CompanyID                                        CompanyName
# 0            1                                   3Com Corporation
# 1            2                                 Abitibi-Price Inc.
# 2            3                                        ADT Limited
# 3            4                     Advanta Corp. Credit card unit
# 4            5                      AirTouch Communications, Inc.
# 5            6                                   Alex. Brown Inc.
# 6            7                        Allegheny Power System Inc.
# 7          277                              Allied Colloids Group
# 8            8                          Allied Irish Banks P.L.C.
# 9          318              American Bankers Insurance Group Inc.
# 10         313                        American Electric Power Co.
# 11           9  American Electric Power Co. Inc. and Public Se...
# 12          10                             American General Corp.
# 13         319                  American International Group Inc.
# 14          11                    American Medical Response, Inc.
# 15          12                       American Radio Systems Corp.
# 16          13                  American Standard Companies, Inc.
# 17          14                    American States Financial Corp.
# 18          15                           Amerisource Health Corp.
# 19          16                                     Amphenol Corp.
# 20         273                                    Apollo Advisors
# 21          17                             Apollo Management L.P.
# 22          18                            Applied Magnetics Corp.
# 23          19                        Apria Healthcare Group Inc.
# 24          20                        Ascend Communications, Inc.
# 25          21                               Associated Banc-Corp
# 26         316                                 AT&T Capital Corp.
# 27          22                                  B.F. Goodrich Co.
# 28          23                               Banc One Corporation
# 29          24                 Bankers Trust New York Corporation
# ..         ...                                                ...
# 288        247                 Union Pacific Resources Group Inc.
# 289        283                              United Meridian Corp.
# 290        248                         United Waste Systems, Inc.
# 291        249                    Universal Outdoor Holdings Inc.
# 292        250                            Universal Studios, Inc.
# 293        251                                       USA Networks
# 294        252                            USA Waste Services Inc.
# 295        253                                       USLIFE Corp.
# 296        254                                Valero Energy Corp.
# 297        255                                 Value Health, Inc.
# 298        256                                       Vencor, Inc.
# 299        257                                     Verifone, Inc.
# 300        258                                 Viacom Radio Group
# 301        259                                         Vivra Inc.
# 302        284                                             VNU NV
# 303        260                               Wachovia Corporation
# 304        261                              Wal-Mart Stores, Inc.
# 305        262                             Washington Mutual Inc.
# 306        263                             Western National Corp.
# 307        264                            Western Resources, Inc.
# 308        265                            Westin Hotels & Resorts
# 309        266                        Westinghouse Electric Corp.
# 310        267                      Westinghouse Power Generation
# 311        301                                      Williams Cos.
# 312        268                                     WorldCom, Inc.
# 313        269                                Wyndham Hotel Corp.
# 314        270                    Yorkshire Electricity Group plc
# 315        271                                Zell/Chillmark Fund
# 316        281                                  Zilkha Energy Co.
# 317        272                                       Zurich Group
#
# [318 rows x 2 columns]

# %% [markdown]
# ## %sql Magic Check
# If the following cells fail, then either ...
# * The database connection failed or
# * Pandas is not imported or
# * The wrong version of ipython-sql is installed; want v0.3.8 or later

# %%
# Connect to the deals database
# %sql mysql+pymysql://dealsuser:deals@localhost/deals
# Out:
# 'Connected: dealsuser@deals'

# %%
# %%sql
# select *
# from Companies
# where rownum > 5
# order by CompanyID
# Out:
#  * mysql+pymysql://dealsuser:***@localhost/deals
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# /opt/tljh/user/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1229                     self.dialect.do_execute(
# -> 1230                         cursor, statement, parameters, context
#    1231                     )
#
# /opt/tljh/user/lib/python3.6/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     535     def do_execute(self, cursor, statement, parameters, context=None):
# --> 536         cursor.execute(statement, parameters)
#     537
#
# /opt/tljh/user/lib/python3.6/site-packages/pymysql/cursors.py in execute(self, query, args)
#     169
# --> 170         result = self._query(query)
#     171         self._executed = query
#
# /opt/tljh/user/lib/python3.6/site-packages/pymysql/cursors.py in _query(self, q)
#     327         self._clear_result()
# --> 328         conn.query(q)
#     329         self._do_get_result()
#
# /opt/tljh/user/lib/python3.6/site-packages/pymysql/connections.py in query(self, sql, unbuffered)
#     892         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 893         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     894         return self._affected_rows
#
# /opt/tljh/user/lib/python3.6/site-packages/pymysql/connections.py in _read_query_result(self, unbuffered)
#    1102             result = MySQLResult(self)
# -> 1103             result.read()
#    1104         self._result = result
#
# /opt/tljh/user/lib/python3.6/site-packages/pymysql/connections.py in read(self)
#    1395         try:
# -> 1396             first_packet = self.connection._read_packet()
#    1397
#
# /opt/tljh/user/lib/python3.6/site-packages/pymysql/connections.py in _read_packet(self, packet_type)
#    1058         packet = packet_type(buff, self.encoding)
# -> 1059         packet.check_error()
#    1060         return packet
#
# /opt/tljh/user/lib/python3.6/site-packages/pymysql/connections.py in check_error(self)
#     383             if DEBUG: print("errno =", errno)
# --> 384             err.raise_mysql_exception(self._data)
#     385
#
# /opt/tljh/user/lib/python3.6/site-packages/pymysql/err.py in raise_mysql_exception(data)
#     108     errorclass = error_map.get(errno, InternalError)
# --> 109     raise errorclass(errno, errval)
#
# InternalError: (1054, "Unknown column 'rownum' in 'where clause'")
#
# The above exception was the direct cause of the following exception:
#
# InternalError                             Traceback (most recent call last)
# <ipython-input-9-cd70c27b77b0> in <module>()
# ----> 1 get_ipython().run_cell_magic('sql', '', 'select *\nfrom Companies \nwhere rownum > 5\norder by CompanyID')
#
# /opt/tljh/user/lib/python3.6/site-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2165             magic_arg_s = self.var_expand(line, stack_depth)
#    2166             with self.builtin_trap:
# -> 2167                 result = fn(magic_arg_s, cell)
#    2168             return result
#    2169
#
# <decorator-gen-126> in execute(self, line, cell, local_ns)
#
# /opt/tljh/user/lib/python3.6/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# <decorator-gen-125> in execute(self, line, cell, local_ns)
#
# /opt/tljh/user/lib/python3.6/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /opt/tljh/user/lib/python3.6/site-packages/sql/magic.py in execute(self, line, cell, local_ns)
#      93
#      94         try:
# ---> 95             result = sql.run.run(conn, parsed['sql'], self, user_ns)
#      96
#      97             if result is not None and not isinstance(result, str) and self.column_local_vars:
#
# /opt/tljh/user/lib/python3.6/site-packages/sql/run.py in run(conn, sql, config, user_namespace)
#     338             else:
#     339                 txt = sqlalchemy.sql.text(statement)
# --> 340                 result = conn.session.execute(txt, user_namespace)
#     341             _commit(conn=conn, config=config)
#     342             if result and config.feedback:
#
# /opt/tljh/user/lib/python3.6/site-packages/sqlalchemy/engine/base.py in execute(self, object_, *multiparams, **params)
#     972             raise exc.ObjectNotExecutableError(object_)
#     973         else:
# --> 974             return meth(self, multiparams, params)
#     975
#     976     def _execute_function(self, func, multiparams, params):
#
# /opt/tljh/user/lib/python3.6/site-packages/sqlalchemy/sql/elements.py in _execute_on_connection(self, connection, multiparams, params)
#     271     def _execute_on_connection(self, connection, multiparams, params):
#     272         if self.supports_execution:
# --> 273             return connection._execute_clauseelement(self, multiparams, params)
#     274         else:
#     275             raise exc.ObjectNotExecutableError(self)
#
# /opt/tljh/user/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1091             distilled_params,
#    1092             compiled_sql,
# -> 1093             distilled_params,
#    1094         )
#    1095         if self._has_events or self.engine._has_events:
#
# /opt/tljh/user/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1232         except BaseException as e:
#    1233             self._handle_dbapi_exception(
# -> 1234                 e, statement, parameters, cursor, context
#    1235             )
#    1236
#
# /opt/tljh/user/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1450                 util.raise_from_cause(newraise, exc_info)
#    1451             elif should_wrap:
# -> 1452                 util.raise_from_cause(sqlalchemy_exception, exc_info)
#    1453             else:
#    1454                 util.reraise(*exc_info)
#
# /opt/tljh/user/lib/python3.6/site-packages/sqlalchemy/util/compat.py in raise_from_cause(exception, exc_info)
#     294     exc_type, exc_value, exc_tb = exc_info
#     295     cause = exc_value if exc_value is not exception else None
# --> 296     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     297
#     298
#
# /opt/tljh/user/lib/python3.6/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     274             value.__cause__ = cause
#     275         if value.__traceback__ is not tb:
# --> 276             raise value.with_traceback(tb)
#     277         raise value
#     278
#
# /opt/tljh/user/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1228                 if not evt_handled:
#    1229                     self.dialect.do_execute(
# -> 1230                         cursor, statement, parameters, context
#    1231                     )
#    1232         except BaseException as e:
#
# /opt/tljh/user/lib/python3.6/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     534
#     535     def do_execute(self, cursor, statement, parameters, context=None):
# --> 536         cursor.execute(statement, parameters)
#     537
#     538     def do_execute_no_params(self, cursor, statement, context=None):
#
# /opt/tljh/user/lib/python3.6/site-packages/pymysql/cursors.py in execute(self, query, args)
#     168         query = self.mogrify(query, args)
#     169
# --> 170         result = self._query(query)
#     171         self._executed = query
#     172         return result
#
# /opt/tljh/user/lib/python3.6/site-packages/pymysql/cursors.py in _query(self, q)
#     326         self._last_executed = q
#     327         self._clear_result()
# --> 328         conn.query(q)
#     329         self._do_get_result()
#     330         return self.rowcount
#
# /opt/tljh/user/lib/python3.6/site-packages/pymysql/connections.py in query(self, sql, unbuffered)
#     891                 sql = sql.encode(self.encoding, 'surrogateescape')
#     892         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 893         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     894         return self._affected_rows
#     895
#
# /opt/tljh/user/lib/python3.6/site-packages/pymysql/connections.py in _read_query_result(self, unbuffered)
#    1101         else:
#    1102             result = MySQLResult(self)
# -> 1103             result.read()
#    1104         self._result = result
#    1105         if result.server_status is not None:
#
# /opt/tljh/user/lib/python3.6/site-packages/pymysql/connections.py in read(self)
#    1394     def read(self):
#    1395         try:
# -> 1396             first_packet = self.connection._read_packet()
#    1397
#    1398             if first_packet.is_ok_packet():
#
# /opt/tljh/user/lib/python3.6/site-packages/pymysql/connections.py in _read_packet(self, packet_type)
#    1057
#    1058         packet = packet_type(buff, self.encoding)
# -> 1059         packet.check_error()
#    1060         return packet
#    1061
#
# /opt/tljh/user/lib/python3.6/site-packages/pymysql/connections.py in check_error(self)
#     382             errno = self.read_uint16()
#     383             if DEBUG: print("errno =", errno)
# --> 384             err.raise_mysql_exception(self._data)
#     385
#     386     def dump(self):
#
# /opt/tljh/user/lib/python3.6/site-packages/pymysql/err.py in raise_mysql_exception(data)
#     107         errval = data[3:].decode('utf-8', 'replace')
#     108     errorclass = error_map.get(errno, InternalError)
# --> 109     raise errorclass(errno, errval)
#
# InternalError: (pymysql.err.InternalError) (1054, "Unknown column 'rownum' in 'where clause'") [SQL: 'select *\nfrom Companies \nwhere rownum > 5\norder by CompanyID'] (Background on this error at: http://sqlalche.me/e/2j85)
